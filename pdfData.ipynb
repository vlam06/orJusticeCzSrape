# %%
import camelot
import pandas as pd
import numpy as np

# %%
tables = camelot.read_pdf('download/seb0a20_vz_cz.pdf')
# Out:
# UserWarning: page-1 is image-based, camelot only works on text-based pages. [lattice.py:411]

# %%
print("Total tables extracted:", tables.n)
# Out:
# Total tables extracted: 0

# %%
import pytesseract
from pdf2image import convert_from_path
import glob

pdfs = glob.glob("download\*.pdf")

for pdf_path in pdfs:
    pages = convert_from_path(pdf_path, 500)

    for pageNum,imgBlob in enumerate(pages):
        text = pytesseract.image_to_string(imgBlob,lang='eng')

        with open(f'{pdf_path[:-4]}_page{pageNum}.txt', 'w') as the_file:
            the_file.write(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     457             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 458         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     459
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] Systém nemůže nalézt uvedený soubor
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7956/2480835092.py in <module>
#       6
#       7 for pdf_path in pdfs:
# ----> 8     pages = convert_from_path(pdf_path, 500)
#       9
#      10     for pageNum,imgBlob in enumerate(pages):
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#      96         poppler_path = poppler_path.as_posix()
#      97
# ---> 98     page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#      99
#     100     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path, rawdates, timeout)
#     482
#     483     except OSError:
# --> 484         raise PDFInfoNotInstalledError(
#     485             "Unable to get page count. Is poppler installed and in PATH?"
#     486         )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
# Out:
#   File "C:\Users\mates\AppData\Local\Temp/ipykernel_7956/1020246908.py", line 1
#     pip3 install ocrmypdf
#          ^
# SyntaxError: invalid syntax

# %%
from tabula import read_pdf
from tabulate import tabulate

#reads the table from pdf file

df = read_pdf("download/seb0a20_vz_cz.pdf",pages="all") #address of pdf file
print(tabulate(df))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      79     try:
# ---> 80         result = subprocess.run(
#      81             args,
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] Systém nemůže nalézt uvedený soubor
#
# During handling of the above exception, another exception occurred:
#
# JavaNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7956/2385252602.py in <module>
#       4 #reads the table from pdf file
#       5
# ----> 6 df = read_pdf("download/seb0a20_vz_cz.pdf",pages="all") #address of pdf file
#       7 print(tabulate(df))
#
# ~\anaconda3\lib\site-packages\tabula\io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     320
#     321     try:
# --> 322         output = _run(java_options, kwargs, path, encoding)
#     323     finally:
#     324         if temporary:
#
# ~\anaconda3\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      89         return result.stdout
#      90     except FileNotFoundError:
# ---> 91         raise JavaNotFoundError(JAVA_NOT_FOUND_ERROR)
#      92     except subprocess.CalledProcessError as e:
#      93         logger.error("Error from tabula-java:\n{}\n".format(e.stderr.decode(encoding)))
#
# JavaNotFoundError: `java` command is not found from this Python process.Please ensure Java is installed and PATH is set for `java`

# %%
# Out:
#
#
#
#
#
#
# Výroční zpráva
#
#
# 2020
#
#
#
# EXCALIBUR INTERNATIONAL a.s.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Obsah
# 1.  Základní údaje o společnosti ........................................................................................................... 3
# 2.  Údaje o činnosti ............................................................................................................................... 3
# 3.  Údaje o důležitých skutečnostech, které nastaly po rozvahovém dni ............................................ 4
# 4.  Údaje o předpokládaném vývoji činnosti ........................................................................................ 4
# 5.  Údaje o nabytí vlastních akcií nebo vlastních podílů ...................................................................... 4
# 6.  Údaje o aktivitách v oblasti výzkumu a vývoje ................................................................................ 4
# 7.  Údaje o aktivitách v oblasti ochrany životního prostředí a pracovněprávních vztazích ................. 4
# 8.  Údaje o tom, zda má účetní jednotka pobočku podniku v zahraničí .............................................. 5
#
# Účetní závěrka za rok končící k 31. 12. 2020
# Zpráva o vztazích za rok končící k 31. 12. 2020
# Zpráva auditora
#
#
# 1.  Základní údaje o společnosti
# Obchodní jméno     EXCALIBUR INTERNATIONAL a.s.
# Sídlo  Sokolovská 675/9, 186 00 Praha 8
# IČ    292 896 88
# Datum vzniku  12. srpna 2011
# Právní forma  Akciová společnost
# Viktor Loužil, člen představenstva
# Statutární orgán  Jaroslav Skála, člen dozorčí rady
# 2 000 000,-Kč, splacen v plné výši a ke dni účetní závěrky
# Výroba, obchod a služby neuvedené v přílohách 1 až 3
# Základní kapitál
# živnostenského zákona
# Nákup a prodej výbušnin
# Nákup a prodej, půjčování, vývoj, výroba, opravy, úpravy,
# uschovávání, skladování, přeprava, znehodnocování a ničení
# bezpečnostního materiálu
# Vývoj, výroba, opravy, úpravy, přeprava, nákup, prodej,
# půjčování, uschovávání, znehodnocování a ničení zbraní
# Předmět podnikání
# a střeliva
# Provádění zahraničního obchodu s vojenským materiálem
# v rozsahu povolení vydaného podle zákona č. 38/1994 Sb.
# v platném znění
# Provádění zahraničního obchodu s vojenským materiálem
# v rozsahu povolení vydaného podle zákona č. 38/1994 Sb.
# v platném znění
# Společnost je zapsána do obchodního rejstříku, vedeného Městským soudem v Praze,
# v oddíle B, vložka 20148
#
# 2.  Údaje o činnosti
# Společnost v roce 2020 pokračovala v obchodních službách v obranném průmyslu. Mezi
# nejvýznamnější projekty patří dodávky do Indonésie a Nigérie. K 31. 12. 2020 byla úspěšně
# ukončena dodávka do Indonésie.  Ukončení dodávky do Nigérie je plánováno v polovině roku
# 2021.
# Společnost  dosáhla  obratu  z prodeje  služeb  a  zboží  ve  výši  3.002.804  tis.  Kč,  což  činí
# zdvojnásobení tržeb oproti předchozímu roku.
#
#
#
# 3.  Údaje o důležitých skutečnostech, které nastaly po rozvahovém dni
# Vedení účetní jednotky zvážilo přetrvávající potenciální dopady COVID-19 na své aktivity
# a dospělo k názoru, že nemají významný vliv na předpoklad nepřetržitého trvání. Aktuální
# dopady mají minimální vliv na hlavní projekty (časové posuny dodávek, úpravy přepravních
# tras).
# Na základě výše uvedeného není třeba upravovat stávající metody účtování a oceňování,
# nemění se životnost a znehodnocení aktiv, nepřehodnocuje se prodejnost a ocenění zásob.
# Rovněž nejsou dotčeny předpoklady návratnosti a ocenění pohledávek.
# V tomto smyslu byla zpracována účetní závěrka.
# Po rozvahovém dni došlo k odkoupení akcií společnosti CSG USA Ltd. od mateřské společnosti
# Czechoslovak Group a. s. a společnost se tak stala 100% akcionářem společnosti CSG USA Ltd.
#
# 4.  Údaje o předpokládaném vývoji činnosti
# Společnost předpokládá, že bude nadále rozvíjet svoji činnost v předmětu podnikání.
# Snahou společnosti je nadále upevnit své postavení na trhu, otevírat nové trhy na území Jižní
# Ameriky, Afriky a na Dálném východě.  Společnost plánuje soustavně rozvíjet vnitřní potenciál
# firmy a nadále dosahovat zvýšení obratu a ziskovosti v roce 2021 a dalších.
#
# 5.  Údaje o nabytí vlastních akcií nebo vlastních podílů
# Účetní jednotka nevlastní žádné vlastní obchodní podíly.
#
# 6.  Údaje o aktivitách v oblasti výzkumu a vývoje
# Společnost nevyvíjela v roce 2020 žádné aktivity v oblasti výzkumu a vývoje.
#
# 7.  Údaje o aktivitách v oblasti ochrany životního prostředí a pracovněprávních
# vztazích
# K problematice životního prostředí lze konstatovat, že společnost dodržuje všechny zákonné
# normy a předpisy a svou činností nenarušuje životní prostředí.
# Společnost zaměstnávala k 31. 12. 2020 na HPP celkem 24 zaměstnanců, a i v této oblasti
# dodržuje veškerou platnou legislativu.
#
#
#
#
#
# Účetní závěrka za rok končící k 31. 12. 2020
#
#
#
#
# ROZVAHA EXCALIBUR INTERNATIONAL a.s.
# v plném rozsahu IČO 292 89 688
# k datu Sokolovská 675/9, Karlín
# 31.12.2020 186 00 Praha 8
# (v tisících Kč)
# 31.12.2020 31.12.2019
# Brutto Korekce Netto Netto
# AKTIVA CELKEM 2 430 150 65 862 2 364 288 2 203 056
# B. Stálá aktiva 2 376 1 366 1 010 1 194
# B.I. Dlouhodobý nehmotný majetek 171 171
# VLASTNÍHO KAPITÁLU IČO 292 89 688
# k datu Sokolovská 675/9, Karlín
# 31.12.2020 186 00 Praha 8
# (v tisících Kč)
# Nerozdělený zisk  Jiný výsledek  Rozhodnuto o
# Fondy ze zisku, rezervní  Výsledek hospodaření
# Základní kapitál Kapitálové fondy nebo neuhrazená  hospodaření  zálohové výplatě  VLASTNÍ KAPITÁL CELKEM
# fond běžného účetního období
# ztráta minulých let minulých let podílu na zisku
# Stav k 31.12.2018 2 000 19 537 11 067 32 604
# Rozdělení výsledku hospodaření 11 067 -11 067
# Ostatní -1 -1
# Výsledek hospodaření za běžné období 4 401 4 401
# Stav k 31.12.2019 2 000 30 603 4 401 37 004
# Rozdělení výsledku hospodaření 4 401 -4 401
# Výsledek hospodaření za běžné období 98 264 98 264
# Stav k 31.12.2020 2 000 35 004 98 264 135 268
# PŘEHLED O PENĚŽNÍCH EXCALIBUR INTERNATIONAL a.s.
# TOCÍCH (CASH FLOW) IČO 292 89 688
# období končící k Sokolovská 675/9, Karlín
# 31.12.2020 186 00 Praha 8
# (v tisících Kč)
# Období do Období do
# 31.12.2020 31.12.2019
# P. Počáteční stav peněžních prostředků a peněžních ekvivalentů 183 042 7 970
# Počáteční stav peněžních prostředků a peněžních ekvivalentů po přeměně
# Peněžní toky z hlavní výdělečné činnosti (provozní činnost)
# Z. Výsledek hospodaření před zdaněním 120 233 5 564
# A.1. Úpravy o nepeněžní operace 112 194 22 904
# A.1.1. Odpisy stálých aktiv 2 893 431
# A.1.2. Změna stavu opravných položek a rezerv  59 151 3 500
# A.1.3. Zisk (ztráta) z prodeje stálých aktiv -5 500 -36
# A.1.5. Nákladové a výnosové úroky 1 891 2 939
# A.1.6. Opravy o ostatní nepeněžní operace 53 759 16 070
# A.* Čistý provozní peněžní tok před změnami pracovního kapitálu 232 427 28 468
# A.2. Změna stavu pracovního kapitálu -236 577 125 660
# A.2.1. Změna stavu pohledávek a časového rozlišení aktiv -922 306 -569 676
# A.2.2. Změna stavu závazků a časového rozlišení pasív -74 177 1 383 709
# A.2.3. Změna stavu zásob 759 906 -688 373
# A.** Čistý provozní peněžní tok před zdaněním -4 150 154 128
# A.3. Vyplacené úroky -3 667 -2 243
# A.4. Přijaté úroky 2 562 22
# A.5. Zaplacená daň z příjmů za běžnou činnost -615 499
# A.*** Čistý peněžní tok z provozní činnosti -5 870 152 406
# Peněžní toky z investiční činnosti
# B.1. Výdaje spojené s nabytím stálých aktiv -145 171 -26
# B.2. Příjmy z prodeje stálých aktiv 147 962 455
# B.3. Zápůjčky a úvěry spřízněným osobám -292 034 -1 331
# B.*** Čistý peněžní tok z investiční činnosti -289 243 -902
# Peněžní toky z finančních činností
# C.1. Změna stavu závazků z financování 137 001 23 568
# C.*** Čistý peněžní tok z finanční činnosti 137 001 23 568
# F. Čistá změna peněžních prostředků a peněžních ekvivalentů -158 112 175 072
# R. Konečný stav peněžních prostředků a peněžních ekvivalentů 24 930 183 042
#
#
#
#
#
#
#
#
#
#
#
#
#
# PŘÍLOHA ÚČETNÍ ZÁVĚRKY ZA ROK 2020
#
#
# Název společnosti:  EXCALIBUR INTERNATIONAL a.s.
#
# Sídlo:  Sokolovská 675/9, Karlín, 186 00 Praha 8
#
# Právní forma:  akciová společnost
#
# IČO:  292 89 688
# Příloha účetní závěrky za rok 2020
#
# OBSAH
# 1.  OBECNÉ ÚDAJE............................................................................................................................... 3
# 1.1.  ZALOŽENÍ A CHARAKTERISTIKA SPOLEČNOSTI ................................................................................................... 3
# 1.2.  ZMĚNY A DODATKY V OBCHODNÍM REJSTŘÍKU V UPLYNULÉM ÚČETNÍM OBDOBÍ...................................................... 3
# 1.3.  PŘEDSTAVENSTVO A DOZORČÍ RADA K ROZVAHOVÉMU DNI ................................................................................ 3
# 1.4.  IDENTIFIKACE SKUPINY ................................................................................................................................ 3
# 2.  ÚČETNÍ METODY ............................................................................................................................ 4
# 2.1.  DLOUHODOBÝ HMOTNÝ A NEHMOTNÝ MAJETEK .............................................................................................. 4
# 2.2.  FINANČNÍ MAJETEK .................................................................................................................................... 5
# 2.3.  ZÁSOBY ................................................................................................................................................... 5
# 2.4.  POHLEDÁVKY ............................................................................................................................................ 6
# 2.5.  ZÁVAZKY ................................................................................................................................................. 6
# 2.6.  ÚVĚRY .................................................................................................................................................... 6
# 2.7.  REZERVY .................................................................................................................................................. 6
# 2.8.  PŘEPOČTY ÚDAJŮ V CIZÍCH MĚNÁCH NA ČESKOU MĚNU ..................................................................................... 6
# 2.9.  FINANČNÍ LEASING..................................................................................................................................... 6
# 2.10.  VÝNOSY .................................................................................................................................................. 7
# 2.11.  KLASIFIKACE PŮJČEK OD SPŘÍZNĚNÝCH OSOB NEBO POSKYTNUTÝCH SPŘÍZNĚNÝM OSOBÁM ....................................... 7
# 2.12.  POUŽITÍ ODHADŮ ...................................................................................................................................... 7
# 2.13.  ZMĚNY ÚČETNÍCH METOD OPROTI PŘEDCHÁZEJÍCÍMU ÚČETNÍMU OBDOBÍ ............................................................. 7
# 2.14.  PŘEHLED O PENĚŽNÍCH TOCÍCH .................................................................................................................... 7
# 3.  DOPLŇUJÍCÍ ÚDAJE ......................................................................................................................... 8
# 3.1.  DLOUHODOBÝ HMOTNÝ MAJETEK (DHM) ..................................................................................................... 8
# 3.2.  DLOUHODOBÝ FINANČNÍ MAJETEK ................................................................................................................ 8
# 3.3.  ZÁSOBY ................................................................................................................................................... 8
# 3.4.  DLOUHODOBÉ POHLEDÁVKY ........................................................................................................................ 8
# 3.5.  KRÁTKODOBÉ POHLEDÁVKY ......................................................................................................................... 9
# 3.6.  STÁT – DAŇOVÉ POHLEDÁVKY ...................................................................................................................... 9
# 3.7.  KRÁTKODOBÉ POSKYTNUTÉ ZÁLOHY .............................................................................................................. 9
# 3.8.  JINÉ POHLEDÁVKY ...................................................................................................................................... 9
# 3.9.  ČASOVÉ ROZLIŠENÍ AKTIV ............................................................................................................................ 9
# 3.10.  REZERVY .................................................................................................................................................. 9
# 3.11.  DLOUHODOBÉ ZÁVAZKY .............................................................................................................................. 9
# 3.12.  KRÁTKODOBÉ ZÁVAZKY ............................................................................................................................. 10
# 3.13.  KRÁTKODOBÉ PŘIJATÉ ZÁLOHY ................................................................................................................... 10
# 3.14.  BANKOVNÍ ÚVĚRY .................................................................................................................................... 10
# 3.15.  DOHADNÉ ÚČTY PASIVNÍ ........................................................................................................................... 10
# 3.16.  VÝNOSY PŘÍŠTÍCH OBDOBÍ ......................................................................................................................... 10
# 3.17.  ODLOŽENÁ DAŇ ...................................................................................................................................... 11
# 3.18.  VÝNOSY Z BĚŽNÉ ČINNOSTI ........................................................................................................................ 11
# 3.19.  ZAMĚSTNANCI, VEDENÍ SPOLEČNOSTI A STATUTÁRNÍ ORGÁNY .......................................................................... 11
# 3.20.  NÁKUP SLUŽEB ....................................................................................................................................... 11
# 3.21.  OSTATNÍ PROVOZNÍ VÝNOSY A NÁKLADY ...................................................................................................... 11
# 3.22.  OSTATNÍ FINANČNÍ VÝNOSY A NÁKLADY ....................................................................................................... 12
# 3.23.  TRANSAKCE A VZTAHY SE SPŘÍZNĚNÝMI SUBJEKTY ........................................................................................... 12
# 3.24.  ZÁVAZKY NEUVEDENÉ V ROZVAZE ............................................................................................................... 13
# 3.25.  NEPŘETRŽITÉ TRVÁNÍ JEDNOTKY ................................................................................................................. 13
# 3.26.  UDÁLOSTI, KTERÉ NASTALY PO DATU ÚČETNÍ ZÁVĚRKY .................................................................................... 14
# EXCALIBUR INTERNATIONAL a.s.    2
#
# Příloha účetní závěrky za rok 2020
#
# 1.  OBECNÉ ÚDAJE
# 1.1.  Založení a charakteristika společnosti
# EXCALIBUR INTERNATIONAL a.s. (dále jen „společnost“) byla založena zakladatelskou
# listinou jako akciová společnost a vznikla zapsáním do obchodního rejstříku soudu
# v Praze dne 12. srpna 2011.
#
# Předmětem podnikání společnosti je:
#
# −  nákup a prodej výbušnin, nákup a prodej, půjčování, vývoj, výroba, opravy,
# úpravy,  uschovávání,  skladování,  přeprava,  znehodnocování  a  ničení
# bezpečnostního materiálu,
# −  vývoj, výroba, opravy, úpravy, přeprava, nákup, prodej, půjčování, uschovávání,
# znehodnocování a ničení zbraní a střeliva,
# −  výroba, obchod a služby neuvedené v přílohách 1 až 3 živnostenského zákona,
# −  provádění zahraničního obchodu s vojenským materiálem v rozsahu povolení
# vydaného podle zákona č. 38/1994 Sb. v platném znění.
# Fyzické a právnické osoby podílející se více než 20 % na základním kapitálu společnosti
# a výše jejich podílu jsou uvedeny v následující tabulce:
#
# CZECHOSLOVAK GROUP a.s.  90 % podíl na základním kapitálu
# ORBITER HOLDING a.s.  10 % podíl na základním kapitálu
# 1.2.  Změny a dodatky v obchodním rejstříku v uplynulém účetním období
# Za uplynulé účetní období 2020 došlo k následujícím změnám v obchodním rejstříku.
#
# Předseda      Ilona Kadlecová    vznik členství 9.3.2020
# Předseda       Ilona Kadlecová    zánik členství 18.12.2020
# Člen        Jana Tonová      vznik členství 6.3.2020
# Člen        Jana Tonová      zánik členství 9.6.2020
# Člen        Viktor Loužil      vznik členství 18.12.2020
# 1.3.  Představenstvo a dozorčí rada k rozvahovému dni
#   Funkce  Jméno
# Představenstvo  Člen  Viktor Loužil
# Dozorčí rada  Člen  Jaroslav Skála
# 1.4.  Identifikace skupiny
# Konsolidovanou účetní závěrku nejširší skupiny účetních jednotek, ke které společnost
# jako konsolidovaná účetní jednotka patří, sestavuje CZECHOSLOVAK GROUP a.s. se
# sídlem v ulici Pernerova 691/42, Karlín, 186 00, Praha 8. Tuto konsolidovanou účetní
# závěrku je možné získat v sídle konsolidující společnosti.
# EXCALIBUR INTERNATIONAL a.s.    3
#
# Příloha účetní závěrky za rok 2020
#
# 2.  ÚČETNÍ METODY
# Účetnictví společnosti je vedeno a účetní závěrka byla sestavena v souladu se zákonem
# č. 563/1991 Sb. o účetnictví v platném znění, vyhláškou č. 500/2002 Sb., kterou se
# provádějí některá ustanovení zákona č. 563/1991 Sb. o účetnictví, pro účetní jednotky,
# které jsou podnikateli účtujícími v soustavě podvojného účetnictví, v platném znění
# a Českými účetními standardy pro podnikatele v platném znění.
#
# Účetnictví respektuje obecné účetní zásady, především zásadu o oceňování majetku
# historickými cenami (není-li dále uvedeno jinak), zásadu účtování ve věcné a časové
# souvislosti, zásadu opatrnosti a předpoklad o schopnosti účetní jednotky pokračovat ve
# svých aktivitách.
#
# Účetní závěrka společnosti je sestavena k rozvahovému dni 31. 12. 2020 za kalendářní
# rok 2020.
#
# Finanční údaje v této účetní závěrce jsou vyjádřeny v tisících korun českých (Kč), není-li
# dále uvedeno jinak.
# 2.1.  Dlouhodobý hmotný a nehmotný majetek
# Dlouhodobým majetkem se rozumí majetek, jehož doba použitelnosti je delší než jeden
# rok a jehož ocenění je v jednotlivém případě vyšší než 40 tis. Kč u hmotného majetku,
# a 60 tis. Kč u nehmotného majetku.
#
# Nakoupený  dlouhodobý  hmotný  a  nehmotný  majetek  je  oceněn  pořizovací  cenou
# sníženou o oprávky a případné opravné položky.
#
# Technické zhodnocení, pokud převýšilo v úhrnu za zdaňovací období u jednotlivého
# hmotného majetku částku 40 tis. Kč a u jednotlivého nehmotného majetku částku
# 60 tis. Kč, zvyšuje pořizovací cenu příslušného dlouhodobého majetku.
#
# Pořizovací cena dlouhodobého hmotného a nehmotného majetku, s výjimkou pozemků
# a nedokončených  investic,  je  odpisována  po  dobu  odhadované  životnosti  majetku
# lineární metodou následujícím způsobem:
#
# Druh majetku   Metoda odpisování   Počet let
# (lineární)
# Stroje, přístroje a zařízení  Lineární  4-12 let
# Automobily  Lineární  5 let
# Drobný dlouhodobý majetek  Lineární  2 roky
#
# Majetek pořízený formou finančního leasingu je odpisován u pronajímatele.
#
# Způsob tvorby opravných položek
#
# Na  základě  inventarizace  nebyly  vytvořeny  opravné  položky  k  dlouhodobému
# hmotnému a nehmotnému majetku.
# EXCALIBUR INTERNATIONAL a.s.    4
#
# Příloha účetní závěrky za rok 2020
#
# 2.2.  Finanční majetek
# Finanční majetek s dobou splatnosti nebo se záměrem držby nad jeden rok se vykazuje
# jako  dlouhodobý,  finanční  majetek  s dobou  splatnosti nebo  se  záměrem  držby  do
# jednoho roku jako krátkodobý.
#
# Ocenění finančního majetku při pořízení
#
# Podíly, cenné papíry a deriváty jsou při pořízení oceněny pořizovací cenou, včetně ážia
# a nákladů s pořízením souvisejících.
#
# Deriváty jsou vykázány v rozvaze v reálné hodnotě. Kladné reálné hodnoty derivátů jsou
# vykázány v aktivech v položce „Jiné pohledávky“. Záporné reálné hodnoty derivátů jsou
# vykázány v závazcích v položce „Jiné závazky“. Reálná hodnota finančních derivátů se
# stanovuje jako současná hodnota očekávaných peněžních toků plynoucích z těchto
# transakcí.
#
# Deriváty k obchodování
# Deriváty  držené  za  účelem  obchodování  jsou  vykazovány  v rozvaze  v  reálných
# hodnotách. Zisky a ztráty ze změny reálných hodnot jsou zachyceny ve výkazu zisku
# a ztráty v položkách „Ostatní finanční výnosy“, resp. „Ostatní finanční náklady“.
#
# Ocenění finančního majetku ke konci rozvahového dne
#
# Cenné papíry určené k obchodování, ostatní realizovatelné cenné papíry a deriváty se
# oceňují reálnou hodnotou. Není-li objektivně možné stanovit reálnou hodnotu, ocení se
# cenné papíry pořizovací cenou, sníženou o opravné položky.
#
# Cenné papíry s pevným výnosem držené do splatnosti se oceňují pořizovací cenou
# zvýšenou nebo sníženou o úrokový výnos nebo náklad.
# 2.3.  Zásoby
# Nakupované zásoby jsou oceňovány pořizovacími cenami. Pořizovací cena zahrnuje cenu
# pořízení a vedlejší pořizovací náklady, zejména celní poplatky, dopravné a skladovací
# poplatky.
#
# Nedokončenou výrobu a výrobky v minulém roce představovaly rozpracované projekty,
# které zahrnují přímé náklady a související část nepřímých nákladů.
#
# Opravné  položky  k  zásobám  jsou  tvořeny  v  případech,  kdy  snížení  ocenění  zásob
# v účetnictví není trvalého charakteru, např. na základě věkové analýzy zásob, dále (je-li
# relevantní) na základě analýzy prodejních cen, (je-li relevantní) atd.
#
# Úbytek zboží je oceňován metodou FIFO.
#
# EXCALIBUR INTERNATIONAL a.s.    5
#
# Příloha účetní závěrky za rok 2020
#
# 2.4.  Pohledávky
# Pohledávky  jsou  při  vzniku  oceňovány  jmenovitou  hodnotou,  následně  sníženou
# o opravné položky. Společnost stanoví opravné položky k pochybným pohledávkám na
# základě  vlastní  analýzy  platební  schopnosti  svých  zákazníků  a  věkové  struktury
# pohledávek.
# Tvorba a zúčtování opravných položek je vykázána ve výkazu zisku a ztráty v položce
# „Úpravy hodnot pohledávek“.
# 2.5.  Závazky
# Závazky jsou zaúčtovány ve jmenovité hodnotě.
#
# Společnost klasifikuje část dlouhodobých závazků a finančních výpomocí, jejichž doba
# splatnosti je kratší než jeden rok vzhledem k rozvahovému dni, jako krátkodobé.
# 2.6.  Úvěry
# Úvěry jsou zaúčtovány ve jmenovité hodnotě. Za krátkodobý úvěr se považuje i část
# dlouhodobých úvěrů, která je splatná do jednoho roku od data, ke kterému je sestavena
# účetní závěrka.
# 2.7.  Rezervy
# Rezervy jsou určeny k pokrytí závazků nebo nákladů, jejichž povaha je jasně definována
# a  u nichž  je  k  rozvahovému dni buď  pravděpodobné,  že nastanou, nebo  jisté,  že
# nastanou, ale není jistá jejich výše nebo okamžik jejich vzniku.
#
# Rezervu na daň z příjmů vytváří společnost vzhledem k tomu, že okamžik sestavení
# účetní závěrky předchází okamžiku stanovení výše daňové povinnosti. V následujícím
# účetním období společnost rezervu rozpustí a zaúčtuje zjištěnou daňovou povinnost.
#
# V rozvaze je rezerva na daň z příjmů snížena o zaplacené zálohy na daň z příjmů,
# případná výsledná pohledávka je vykázána v položce Stát-daňové pohledávky.
# 2.8.  Přepočty údajů v cizích měnách na českou měnu
# Účetní  operace  v  cizích  měnách  prováděné  během  roku  jsou  účtovány  kurzem
# České národní banky platným ke dni uskutečnění účetního případu. V průběhu roku
# účtuje společnost pouze o realizovaných kurzových ziscích a ztrátách.
#
# K datu účetní závěrky jsou cizoměnová aktiva a pasiva přepočtena kurzem ČNB platným
# k datu, ke kterému je účetní závěrka sestavena. Nerealizované kurzové zisky a ztráty jsou
# zachyceny ve výsledku hospodaření.
# 2.9.  Finanční leasing
# Splátky finančního leasingu jsou účtovány do nákladů. Navýšená první splátka finančního
# leasingu je časově rozlišena a rozpouštěna po dobu pronájmu do nákladů.
# EXCALIBUR INTERNATIONAL a.s.    6
#
# Příloha účetní závěrky za rok 2020
#
# 2.10. Výnosy
# Výnosy z obranného průmyslu se účtují v okamžiku, s nímž věcně i časově souvisejí.
#
# Výnosy jsou zaúčtovány v hodnotě přijatého plnění nebo plnění, které bude přijato,
# a představují pohledávky za zboží a služby poskytnuté v průběhu běžné činnosti, po
# odečtení slev, daně z přidané hodnoty a dalších daní souvisejících s prodeji.
#
# Tržby  z prodeje  zboží  jsou  zaúčtovány  v okamžiku,  kdy  dojde  k doručení  zboží
# a převedení práv vztahujících se k tomuto zboží.
# 2.11. Klasifikace půjček od spřízněných osob nebo poskytnutých spřízněným osobám
# Půjčky přijaté či poskytnuté společnostem v rámci konsolidačního celku CZECHOSLOVAK
# GROUP a.s. jsou v rozvaze klasifikovány jako pohledávky či závazky – ovládaná nebo
# ovládající osoba.
# 2.12. Použití odhadů
# Sestavení  účetní  závěrky  vyžaduje,  aby  vedení  společnosti  používalo  odhady
# a předpoklady, jež mají vliv na vykazované hodnoty majetku a závazků k datu účetní
# závěrky  a  na  vykazovanou  výši  výnosů  a  nákladů  za  sledované  období.  Vedení
# společnosti stanovilo tyto odhady a předpoklady na základě všech jemu dostupných
# relevantních informací. Nicméně, jak vyplývá z podstaty odhadu, skutečné hodnoty
# v budoucnu se mohou od těchto odhadů odlišovat.
#
# Odhady  a  předpoklady  jsou  průběžně  revidovány.  Úpravy  účetních  odhadů  jsou
# zohledněny v období, ve kterém jsou tyto odhady revidovány, pokud se revize týká
# pouze daného účetního období, nebo v období revize a budoucích obdobích, pokud
# revize ovlivňuje současné i budoucí období.
# 2.13. Změny účetních metod oproti předcházejícímu účetnímu období
# Společnost k 1. lednu 2020 nezměnila účetní metodu.
# 2.14. Přehled o peněžních tocích
# Přehled  o  peněžních  tocích  byl  sestaven  nepřímou  metodou.  Peněžní  ekvivalenty
# představují krátkodobý likvidní majetek, který lze snadno a pohotově převést na předem
# známou částku v hotovosti a u kterého se nepředpokládají významné změny hodnoty
# v čase.
#
# Peněžní prostředky a peněžní ekvivalenty lze analyzovat takto:
# (údaje v tis. Kč)
#   31. 12. 2020  31. 12. 2019
# Pokladní hotovost a peníze na cestě  262  54
# Účty v bankách  24 668  182 988
# Peněžní prostředky a peněžní ekvivalenty celkem   24 930  183 042
#
# Peněžní  toky  z provozních,  investičních  nebo  finančních  činností  jsou  uvedeny
# v přehledu o peněžních tocích nekompenzovaně.
# EXCALIBUR INTERNATIONAL a.s.    7
#
# Příloha účetní závěrky za rok 2020
#
# 3.  DOPLŇUJÍCÍ ÚDAJE
# 3.1.  Dlouhodobý hmotný majetek (DHM)
# Pořizovací cena
# (údaje v tis. Kč)
# Počáteční  Přírůstky   Vyřazení   Převody  Konečný
#
# zůstatek  zůstatek
# Hmotné movité věci a jejich soubory  1 984  145 000  -145 029  0  1 955
# Celkem 2020   1 984  145 000  -145 029  0  1 955
# Celkem 2019  2 831  26  -873  0  1 984
#
# Opravné položky a oprávky
# (údaje v tis. Kč)
# Počáteční  Přírůstky  Úbytky  Převody  Konečný  Opravné  Účetní
#
# zůstatek  zůstatek  položky  hodnota
# Hmotné movité věci a jejich soubory  1 040  2 893  -2 567  0  1 366  0  589
# Celkem 2020  1 040  2 893  -2 567  0  1 366  0  589
# Celkem 2019  1 063  850  -873  0  1 040  0  944
# 3.2.  Dlouhodobý finanční majetek
# Podíly – ovládaná osoba
# (údaje v tis. Kč)
# Obchodní jméno  Sídlo  Výše obch.  Vlastní kapitál  Výsledek hospodaření   Účetní
# společnosti  společnosti  podílu  společnosti*  společnosti*   hodnota
# EXCALIBUR INTERNATIONAL  H01011
# HU Kft.  Budapešť  100  216  -675  250
# Celkem    100  216  -675  250
# * Údaje z neauditované účetní závěrky za rok 2020
# 3.3.  Zásoby
# Zásoby výrobků a zboží ke konci roku 2020 činily 389 325 tis. Kč (2019 – 555 735 tis. Kč).
# Nedokončená výroba ve výši 0 tis. Kč (2019 – 372 516 tis. Kč představuje nedokončené
# činnosti související s projektem M3). Projekt M3 byl ke konci roku 2020 ukončen a z toho
# důvodu je zůstatek na účtu Nedokončené výroby nulový. Veškeré zboží se v roce 2020
# účtuje na účtu Zboží. Na základě provedené inventury zásob byla v roce 2020 vytvořena
# opravná položka na ve výši 0 mil. Kč (v roce 2019 byla vytvořena opravná položka na
# zásoby munice ve skladu Šternberk ve výši 1 mil. Kč).
#
# Poskytnuté zálohy na pořízení zboží byly k 31. prosinci 2020 ve výši 0 Kč (2019 –
# 220 980 Kč).
# 3.4.  Dlouhodobé pohledávky
# Hodnota odložené daňové pohledávky v roce 2020 činí 115 tis. Kč (2019 – 773 tis. Kč).
#
# Pohledávky se splatností delší než 5 let společnost neeviduje.
#
# EXCALIBUR INTERNATIONAL a.s.    8
#
# Příloha účetní závěrky za rok 2020
#
# 3.5.  Krátkodobé pohledávky
# Krátkodobé pohledávky z obchodních vztahů činí 927 026 tis. Kč (2019 – 687 510 tis. Kč),
# ze kterých 534 654 tis. Kč (2019 – 467 949 tis. Kč) představují pohledávky po lhůtě
# splatnosti.
#
# Opravná položka k pochybným pohledávkám k 31. prosinci 2020 činila 64 496 tis. Kč
# (2019 – 4 652 tis. Kč). Společnost neeviduje žádné pohledávky se splatností delší než
# 5 let.
# 3.6.  Stát – daňové pohledávky
# Nejvýznamnější pohledávky, které v rámci této pozice Společnost vykazuje je jednak
# pohledávku z titulu daně z přidané hodnoty ve výši 1 851 tis. Kč (2019 – 12 053 tis. Kč)
# a jednak z titulu daně z příjmu právnických osob ve výši 1 826tis. Kč (2019 - 2 858 tis. Kč).
# Ostatní daně jsou ve výši 0 Kč (2019 - 8 tis. Kč).
# 3.7.  Krátkodobé poskytnuté zálohy
# Krátkodobé  poskytnuté  zálohy představují zaplacené  zálohy  na poskytování  služeb
# v souvislost  s provozem  a  v souvislosti  s otevřenými  projekty  v  celkové  výši
# 460 135 tis. Kč (2019 –97 455 tis. Kč).
# 3.8.  Jiné pohledávky
# V roce 2020 byla na konečném zůstatku pohledávek vůči ČEB částka 13 148 tis. Kč
# (k 31.12.2019  ve  výši  6 390  tis.  Kč).  Další  významnou  položkou  je  pohledávka  za
# společností Dieliana z titulu postoupení pohledávky ve výši 200 088 tis. Kč.
# 3.9.  Časové rozlišení aktiv
# Časové rozlišení aktiv je tvořeno zejména rozlišením k projektu Nigerie. Jsou v něm
# zahrnuty  přepravní  služby  a  pojistné  ve  výši  30  806  tis.  Kč  (k  31.12.2019  ve  výši
# 24 600 tis. Kč)
# 3.10. Rezervy
# (údaje v tis. Kč)
#   Stav k 31. 12. 2020  Stav k 31. 12. 2019
# Rezerva na nevybranou dovolenou  796  119
# Rezerva na rizika projektu   0  370
# Rezerva na daň z příjmu  19 666  0
# Ostatní rezervy celkem  20 462  489
# 3.11. Dlouhodobé závazky
# Společnost neeviduje žádné závazky, jež mají k 31. 12. 2020 dobu splatnosti delší než
# 5 let.
# EXCALIBUR INTERNATIONAL a.s.    9
#
# Příloha účetní závěrky za rok 2020
#
# 3.12. Krátkodobé závazky
# Krátkodobé závazky z obchodních vztahů činí 169 007 tis. Kč (2019 – 434 035 tis. Kč), ze
# kterých 135 174 tis. Kč (2019 – 429 103 tis. Kč) představují závazky po lhůtě splatnosti.
# Posuny plateb odpovídají průběhu projektů.
# 3.13. Krátkodobé přijaté zálohy
# Společnost eviduje k 31. prosinci 2020 krátkodobé přijaté zálohy ve výši 745 994 tis. Kč
# (2019 – 966 104 tis. Kč), které souvisí s probíhajícími zakázkami.
# 3.14. Bankovní úvěry
# Krátkodobé bankovní úvěry obsahují:
# (údaje v tis. Kč)
# Banka/Věřitel  Měna  Zůstatek k 31. 12. 2020  Zůstatek k 31. 12. 2019  Forma zajištění
# COMMERZBANK  zástava pohledávek
# kontokorent  Kč, EUR, USD  0  0  a prostředků na BÚ
# Celkem    0  0
#
# Výše uvedené úvěry splatné do jednoho roku od data účetní závěrky jsou v rozvaze
# vykázány jako součást krátkodobých bankovních úvěrů.
# 3.15. Dohadné účty pasivní
# Společnost eviduje časové rozlišení pasiv z titulu ukončeného projektu M3 k 31.12.2020.
# Jedná se o časové rozlišení nákladů ve výši 190 918 tis. Kč (257 875 tis. Kč v roce 2019)
# z toho manažerský zisk 121 906 tis. Kč a ostatní položky v součtu 69 012 tis. Kč za zboží,
# služby, offsetová školení a poplatky za bankovní záruky.
#
# Dále společnost eviduje dohady na služby v rámci projektu Nigérie 471 964 tis. Kč z toho
# na vyplacení obratového bonusu 204 935 tis. Kč a ostatní služby 267 029 tis. Kč. Dohady
# na ostatní běžné provozní náklady 1 237 tis. Kč.
#
# V roce 2019 společnost evidovala mimo dohady spojené s projektem M3 dohady na
# služby v rámci projektů (149 607 tis. Kč), služby od CSGM a.s. (21 757 tis. Kč), dohad na
# náklady auditu (308 tis. Kč), příjem zboží (3 467 tis. Kč), penále (4 136 tis. Kč) a ostatní
# (2 279 tis. Kč).
# 3.16. Výnosy příštích období
# Výnosy příštích období jsou tvořeny fakturovanými projekty, které budou dodány v roce
# 2021.
#
# EXCALIBUR INTERNATIONAL a.s.    10
#
# Příloha účetní závěrky za rok 2020
#
# 3.17. Odložená daň
# Celkovou existující odloženou daňovou pohledávku lze analyzovat takto:
#  (údaje v tis. Kč)
#   Stav k 31. 12. 2020   Stav k 31. 12. 2019
# Oprávky dlouhodobého majetku   -36  -31
# Pohledávky  0  638
# Rezervy  151  93
# Ostatní  0  73
# Celkem pohledávka  115  773
# 3.18. Výnosy z běžné činnosti
# Nejvýznamnější část položky tržeb představují výnosy spojené s realizací projektu M3 ve
# výši 1 628 tis. Kč a Nigérie ve výši 1 435 tis. Kč.
#
# (údaje v tis. Kč)
#
#    Tuzemsko  Zahraniční  Celkem
# Tržby z prodeje vlastních výrobků a služeb  2020  19 624  1 614 865  1 634 489
#   2019  50  868 674  868 724
# Tržby z prodeje zboží  2020  764  1 367 550  1 368 314
#    2019  0  514 236  514 236
# 3.19. Zaměstnanci, vedení společnosti a statutární orgány
# Počet zaměstnanců a členů vedení společnosti na konci roku 2020 činil 24 osob, z toho
# 3 řídící pracovníci (za rok 2019 – 11 osob, z toho 2 řídící pracovníci). Mzdové náklady
# v roce 2020 byly 17 900 tis. Kč (za rok 2019 – 9 256 tis. Kč), z toho mzdové náklady členů
# vedení činily 6 061 tis. Kč (za rok 2019 – 1 590 tis. Kč).
#
# Společnosti nevznikly do 31. prosince 2020 ani 2019 žádné penzijní závazky vůči bývalým
# členům řídících, kontrolních a správních orgánů.
# 3.20. Nákup služeb
# RETIA, a.s.  Sesterská  -3  0  0  0  -3
# Slovak Training Academy, s.r.o.  Sesterská  242  27 302  0  0  27 544
# STA TECHNOLOGY, s.r.o.  Sesterská  2  0  0  0  2
# TATRA DEFENCE VEHICLE a.s.  Sesterská  35  0  0  0  35
# CZECHOSLOVAK GROUP a.s.  Ovládající  0  0  291 676  0  291 676
# EUROPEAN AIR SERVICES s.r.o.  Sesterská  40  0  21 985  0  22 025
# Celkem     21 111  200 574  316 232  31 044  578 961
#   *Ostatní pohledávky jsou na rozvaze prezentovány v rámci řádku C.II.2.4.6 Jiné pohledávky
#
# Pohledávky a zálohy vůči spřízněným subjektům k 31. 12. 2019
# (údaje v tis. Kč)
# Subjekt  Vztah ke společnosti  Pohledávky  Poskytnuté zálohy  Celkem
# CSGM a.s.  Sesterská  2  4 189   4 191
# Česká letecká servisní a.s.  Sesterská  5  0  5
# ELDIS Pardubice, s.r.o.  Sesterská  80    0  80
# EXCALIBUR ARMY spol. s r.o.  Sesterská  334  148 307  148 641
# MSM Martin, s.r.o.  Sesterská  6 590  5 939  12 529
# New Space Technologies s.r.o.  Spřízněná  -23  0  -23
# RETIA, a.s.  Sesterská  49  0  49
# KOVOSVIT MAS Machine Tools, a.s.  Spřízněná  0  13 000  13 000
# Celkem     7 037  171 435  178 472
# EXCALIBUR INTERNATIONAL a.s.    12
#
# Příloha účetní závěrky za rok 2020
#
# Závazky vůči spřízněným subjektům k 31. 12. 2020
#  (údaje v tis. Kč)
# Subjekt  Vztah ke  Závazky Přijaté zálohy  Zápůjčky  Ostatní  Celkem
# společnosti
# CSGM a.s.  Sesterská  -23 223  0  0  0  -23 223
# CZECHOSLOVAK GROUP a.s.  Sesterská  -1 924  0  0  0  -1 924
# EUROPEAN AIR
# SERVICES s.r.o.  Sesterská  0  0  0  -21 387  -21 387
# EXCALIBUR ARMY spol. s r.o.  Sesterská  -11 833  0  0  0  -11 833
# MSM Martin s.r.o.  Sesterská  -3 561  0  0  0  -3 561
# MSM Nováky, a.s.  Sesterská  -5 643  0  0  0  -5 643
# REAL TRADE PRAHA a.s.  Sesterská  -2 824  0  0  0  -2 824
# VÍTKOVICKÁ DOPRAVA, a.s.  Sesterská  -58  0  0  0   -58
# CSG AEROSPACE a.s.  Sesterská  0  0  -82 244  -38 336  -120 580
# CZECHOSLOVAK GROUP a.s.  Ovládající  0  0  0  -1 321  -1 321
# TATRA DEFENCE VEHICLE a.s.  Sesterská  0  0  0  -61 315  -61 315
# INTEGRA CAPITAL a.s.  Sesterská  0  0  -200 129  0  -200 129
# MSM Nováky, a.s.  Sesterská  0  -22 203  0  0  -22 203
# Celkem     -49 066  -22 203  -282 373  -122 359  -476 001
#
# *  Přijaté zápůjčky a Ostatní jsou na rozvaze společně prezentovány v rámci řádku C.II.6 Závazky - ovládaná nebo ovládající osoba
# Závazky vůči spřízněným subjektům k 31. 12. 2019
#  (údaje v tis. Kč)
# Subjekt  Vztah ke  Krátkodobé  Ostatní Dlouhodobé  Zápůjčky  Ostatní  Celkem
# společnosti z obchodního krátkodobé
#  styku
# CSG AEROSPACE a.s.  Sesterská  0  0  0  93 454  40 248  133 702
# CSG Facility a.s.  Sesterská  845  0  0  0  0  845
# CSGM a.s.  Sesterská   742  0  0  0  0  742
# CZECHOSLOVAK GROUP a.s.  Ovládající  13          0  0  0  0  13
# EUROPEAN AIR SERVICES s.r.o. Sesterská  56  0  0  0  0  56
# EXCALIBUR ARMY spol. s r.o.  Sesterská  351 217         0  0  0  16 035  367 252
# MSM Nováky, a.s.  Sesterská  2  0  0  0  0  2
# New Space Technologies s.r.o.  Sesterská  30 079  0  0  0  0  30 079
# TATRA TRUCKS a.s.  Spřízněná  80  0  0  0  0  80
# Celkem     383 034  0  0  93 454  56 283  532 771
# 3.24. Závazky neuvedené v rozvaze
# Společnost eviduje vystavené bankovní záruky v souvislosti s probíhajícími či budoucími
# zakázkami ve výši 229 219 tis. Kč s platností v 2021 a 2022.
# 3.25. Nepřetržité trvání jednotky
# Vedení účetní jednotky zvážilo přetrvávající potenciální dopady COVID-19 na své aktivity
# a  dospělo  k názoru,  že  nemají  významný  vliv  na  předpoklad  nepřetržitého  trvání.
# Aktuální dopady mají minimální vliv na hlavní projekty (časové posuny dodávek, úpravy
# přepravních tras).
#
# Na základě výše uvedeného není třeba upravovat stávající metody účtování a oceňování,
# nemění se životnost a znehodnocení aktiv, nepřehodnocuje se prodejnost a ocenění
# zásob. Rovněž nejsou dotčeny předpoklady návratnosti a ocenění pohledávek.
#
# V tomto smyslu byla zpracována účetní závěrka.
# EXCALIBUR INTERNATIONAL a.s.    13
#
# Příloha účetní závěrky za rok 2020
#
# 3.26. Události, které nastaly po datu účetní závěrky
# Po rozvahovém dni došlo k odkoupení akcií společnosti CSG USA Ltd. od mateřské
# společnosti  Czechoslovak  Group  a.  s.  a  společnost  se  tak  stala  100%  akcionářem
# společnosti CSG USA Ltd.
#
# EXCALIBUR INTERNATIONAL a.s.    14
#
# Zpráva o vztazích za rok končící k 31. 12. 2020
#
#
#
# Zpráva o vztazích mezi propojenými osobami za rok 2020
#
#
#
#
#
#
#
#
# Zpráva o vztazích mezi propojenými osobami
#
# 2020
#
#
# EXCALIBUR INTERNATIONAL a.s.
#
#
#
#
#
#
#
# Sídlo:        Sokolovská 675/9, Karlín, 186 00 Praha 8
# IČO:         292 89 688
# Ovládající osoba:     CZECHOSLOVAK GROUP a.s.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zpráva o vztazích mezi propojenými osobami za rok 2020
#
#
# I.  Ovládající osoby
#
# Tato zpráva o vztazích mezi níže uvedenými propojenými osobami byla vypracována v souladu
# s ustanovením § 82 zákona č. 90/2012 Sb., o obchodních korporacích.
#
# Ode dne 13. října 2014 do 30. srpna 2020 byla ovládající osobou společnosti EXCALIBUR
# INTERNATIONAL a.s.    (dále také „Společnost“) společnost Czechoslovak Group B.V.
# Společnost Czechoslovak Group B.V. byla v roce 2020 ovládaná panem Michalem Strnadem.
# SHER Technologies a.s., IČO: 275 28 171, se sídlem č.p. 101, 533 32 Čepí, zapsaná v OR
# vedeném u Krajského soudu v Hradci Králové, sp. zn. B 2669
# Skyport a.s., IČO: 078 80 383, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6, zapsaná
# v OR vedeném u Městského soudu v Praze, sp. zn. B 2418824
# Skyport Catering s.r.o., IČO: 036 80 835, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. C 23620025
#
# 19 Součást skupiny do 31. 8. 2020.
# 20 Dne 19. 12. 2020 změna názvu – původní ARS Europe a.s.
# 21 Součást skupiny od 19. 6. 2020.
# 22 Součást skupiny od 19. 6. 2020.
# 23 Součást skupiny do 17. 3. 2020.
# 24 Součást skupiny do 27. 12. 2020; dne 1. 7. 2020 změna názvu (původní CSG a.s.).
# 25 Součást skupiny do 27. 12. 2020.
# Zpráva o vztazích mezi propojenými osobami za rok 2020
#
#
# Skyport Holding a.s., IČO: 278 80 176, se sídlem Laglerové 1075/4, 161 00 Praha 6, zapsaná
# v OR vedeném u Městského soudu v Praze, sp. zn. B 1172826
# Skyport RE a.s., IČO: 053 32 923, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 2178227
# Slovak  Aviation  Factory  s.r.o.,  IČO:  50 885 201,  se  sídlem  Štúrova  925/27,  018  41
# Dubnica nad Váhom, Slovenská republika, zapsaná v OR vedeném u Okresního soudu Trenčín,
# sp. zn. Sro 34705/R
# Slovak  Training  Academy,  s.r.o.,  IČO:  47  055  952,  se  sídlem  Štúrova  925/27,  018  41
# Dubnica nad Váhom, Slovenská republika, zapsaná v OR vedeném u Okresního soudu Trenčín,
# sp. zn. Sro 30298/R
# Space T a.s., IČO: 086 55 600, se sídlem Na poříčí 1071/17, Nové Město, 110 00 Praha 1,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 24808
# SPV REAL ESTATE a.s., IČO: 068 12 716, se sídlem Na poříčí 1071/17, Nové Město,
# 110 00 Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 2323028
# SPVRTP CZ s.r.o., IČO: 069 81 119, se sídlem Na poříčí 1071/17, Nové Město, 110 00 Praha 1,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. C 291189
# STA TECHNOLOGY, s.r.o., IČO: 50 479 717, se sídlem Štúrova 925/27, 018 41 Dubnica
# nad  Váhom,  Slovenská  republika,  zapsaná  v  OR  vedeném  u  Okresního  soudu  Trenčín,
# sp. zn. Sro 33646/R
# TABLON SPV a.s., IČO: 089 50 504, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 2512829
# TATRA a.s., IČO: 092 69 649, se sídlem Na poříčí 1071/17, Nové Město, 110 00 Praha 1,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 2537130
# TATRA AVIATION a.s., IČO: 039 99 203, se sídlem Kodaňská 521/57, Vršovice, 101 00
# Praha 10, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 20535
# TATRA DEFENCE SYSTEMS s.r.o., IČO: 089 93 289, se sídlem Sokolovská 675/9, Karlín,
# 186 00 Praha 8, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. C 32882831
# TATRA DEFENCE VEHICLE a.s., IČO: 241 52 269, se sídlem Kodaňská 521/57, Vršovice,
# 101 00 Praha 10, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B
zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 19432
# INDUSTRY SPV a.s., IČO: 061 85 878, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 22602
# INDUSTRYIN a.s., IČO: 055 95 240, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 21960
# INNOVATION CS a.s., IČO: 018 52 515, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 22092
# KOVOSVIT MAS Foundry, a.s., IČO: 069 78 347, se sídlem náměstí Tomáše Bati 419, 391 02
# Sezimovo  Ústí,  zapsaná  v  OR  vedeném  u  Krajského  soudu  v  Českých  Budějovicích,
# sp. zn. B 240739
# KOVOSVIT MAS Machine Tools, a.s., IČO: 073 33 536, se sídlem náměstí Tomáše Bati 419,
# 391 02 Sezimovo Ústí, zapsaná v OR vedeném u Krajského soudu v Českých Budějovicích,
# sp. zn. B 240640
# KOVOSVIT MAS Management, a.s., IČO: 073 98 778, se sídlem náměstí Tomáše Bati 419,
# 391 02 Sezimovo Ústí, zapsaná v OR vedeném u Krajského soudu v Českých Budějovicích,
# sp. zn. B 240841
# PROJECT SPV a.s., IČO: 061 85 771, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 22601
# Skyport a.s., IČO: 078 80 383, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6, zapsaná
# v OR vedeném u Městského soudu v Praze, sp. zn. B 2418842
# Skyport s.r.o.,  IČO: 31 373 844, se sídlem Letisko M. R. Štefánika,  820 01 Bratislava,
# Slovenská republika, zapsaná v OR vedeném u Okresního soudu Bratislava I, sp. zn. Sro
# 7125/B
# Skyport Catering s.r.o., IČO: 036 80 835, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. C 23620043
# Skyport Holding a.s., IČO: 278 80 176, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 1172844
# Skyport RE a.s, IČO: 053 32 923, se sídlem Laglerové 1075/4, Ruzyně, 161 00 Praha 6, zapsaná
# v OR vedeném u Městského soudu v Praze, sp. zn. B 2178245
# SKYPORT GROUP (UK) PLC, se sídlem Lion House Red Lion Street, London WC1R 4BG
# SYNERGY CS a.s., IČO: 060 72 585, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 22465
# TESLA CS a.s., IČO: 068 61 041, se sídlem Na poříčí 1071/17, Nové Město, 110 00 Praha 1,
# zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 23216
#
# 39 Součást struktury do 1. 10. 2020.
# 40 Součást struktury do 1. 10. 2020.
# 41 Součást struktury do 1. 10. 2020.
# 42 Součást struktury od 28. 12. 2020.
# 43 Součást struktury od 28. 12. 2020.
# 44 Součást struktury od 21. 12. 2020.
# 45 Součást struktury od 21. 12. 2020.
# Zpráva o vztazích mezi propojenými osobami za rok 2020
#
#
# TESLA RADARS a.s., IČO: 068 61 083, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 23217
# VEHICLE SPV a.s., IČO: 065 94 794, se sídlem Na poříčí 1071/17, Nové Město, 110 00
# Praha 1, zapsaná v OR vedeném u Městského soudu v Praze, sp. zn. B 22988
# IV.  Úloha ovládané osoby, způsob a prostředky ovládání
#
# Úlohou  ovládané  Společnosti  je  především  zastřešení  aktivit  dceřiných  společností
# v České republice a na Slovensku.
#
# Ovládání je vůči Společnostem uplatňováno prostřednictvím 100% nebo ovládajícího podílu na
# hlasovacích právech na valné hromadě Společnosti.
#
# V.  Přehled jednání učiněných v roce 2020, která byla učiněna na
# popud nebo v zájmu ovládající osoby nebo jí ovládaných osob,
# pokud se takovéto jednání týkalo majetku, který přesahuje 10 %
# vlastního  kapitálu  ovládané  osoby  zjištěného  podle  poslední
# účetní závěrky
#
# V roce 2020 byly nakoupeny služby a zboží, které přesahují 10% vlastního kapitálu, od
# následujících firem ve skupině:
#
#
# CSG AEROSPACE a.s.  2 782  tis. Kč
# CSG EXPORT a.s.  200  tis. Kč
# CSGM a.s.  49 126  tis. Kč
# CZECHOSLOVAK GROUP a.s.  10 913  tis. Kč
# ELTON hodinářská, a.s.  224  tis. Kč
# EXCALIBUR ARMY spol. s r.o.  424 736  tis. Kč
# MSM Martin s.r.o.  36 111  tis. Kč
# MSM Nováky, a.s.  14 229  tis. Kč
# New Space Technologies s.r.o.  24 265  tis. Kč
# REAL TRADE PRAHA a.s.  3 425  tis. Kč
# Slovak Training Academy, s.r.o.  66 280  tis. Kč
# VÍTKOVICKÁ DOPRAVA, a.s.  710  tis. Kč
#
#
#
#
#
#
#
# Zpráva o vztazích mezi propojenými osobami za rok 2020
#
#
# VI.  Přehled  vzájemných  smluv  mezi  osobou  ovládanou  a  osobou
# ovládající nebo mezi osobami ovládanými
#
# Společnost EXCALIBUR INTERNATIONAL a. s. eviduje smlouvy se společnostmi:
#
# -  CS SOFT a.s. z titulu spolupráce na výstavě
# -  CSG Facility a.s. z titulu poskytování servisních služeb
# -  CSGM a.s. z titulu poskytování servisních služeb
# -  CSG Aerospace a.s. z titulu půjčky
# -  Czechoslovak Group a.s. z titulu zajištění služeb Treasury
# -  Česká letecká servisní a.s. z titulu půjčky
# -  European Air Services s.r.o z titulu pronájmu prostor, výprosy a půjčky
# -  Eldis Pardubice, s.r.o. z titulu spolupráce na výstavě
# -  Excalibur Army spol s.r.o. z titulu dodávek v obranném průmyslu
# -  MSM Martin s.r.o. z titulu dodávek v obranném průmyslu
# -  P F Support s.r.o. z titulu poskytování servisních služeb a pronájmu aut
# -  Excalibur International HU Kft. z titulu poskytnutí půjčky
# -  Retia a.s. z titulu spolupráce na výstavě
#
# Všechny významné transakce se spřízněnýmim osobami byly uskutečněny za běžných tržních
# podmínek, obvyklých v místě a čase, keré by jinak existovaly mezi nezávislými subjekty
# a Společností.
# VII.  Posouzení  újmy  vzniklé  z obchodních  vztahů  s  propojenými
# osobami
#
# Společnost využívá služeb a financování od spřízněných stran v rámci běžné obchodní činnosti
# podniku.
#
# Z výše uvedených smluv, úkonů a ostatních jednání nevznikla Společnosti žádná újma.
#
#
#
# Zpráva auditora
